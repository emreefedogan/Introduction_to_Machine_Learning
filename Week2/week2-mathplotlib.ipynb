# %%
import matplotlib.pyplot as plt 
import numpy as np


x = np.arange(0, 20, 0.2)

y = np.cos(x)


plt.plot(x, y)


plt.title("Cos Grafiği")
plt.xlabel("X Ekseni")
plt.ylabel("Y Ekseni")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


x = np.random.rand(30)
y = np.random.rand(30)
colors = np.random.rand(30)
sizes = np.random.randint(30, 100, 30)

plt.scatter(x, y, c=colors, s=sizes)


plt.title("Point Chart Gosterimi")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

data = np.random.randn(9999)

plt.hist(data, bins=20)

plt.title("Histogram Gosterimi")
plt.xlabel("Values")
plt.ylabel("Frequency")


plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


x = ['A', 'B', 'C', 'D', 'E','F']
y = np.random.randint(1, 10, 6)

plt.bar(x, y)


plt.title("Column Chart")
plt.xlabel("Degiskenler")
plt.ylabel("Degerler")

# Show graphics
plt.show()

# %%
import matplotlib.pyplot as plt

sizes = [30, 234, 345, 32, 345, 456]


plt.pie(sizes)

plt.title("Pie Chart / Dairesel Grafik")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

x = np.arange(-5, 5, 0.25)
y = np.arange(-5, 5, 0.25)
x, y = np.meshgrid(x, y)
r = np.sqrt(x**2 + y**2)
z = np.sin(r)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')


ax.plot_surface(x, y, z)


ax.set_title("3D Graphics")
ax.set_xlabel("X axis")
ax.set_ylabel("Y axis")
ax.set_zlabel("Z axis")

# Show
plt.show()
